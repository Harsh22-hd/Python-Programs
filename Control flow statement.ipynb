# %% [markdown]
# #if Statement

# %%
i = 20
if i>10:
    print("20 is greater than 10")
# Out:
# 20 is greater than 10

# %%
i = 20
if i<10:
    print("20 is greater than 10")
print("Condition is false")
# Out:
# Condition is false

# %%
a = float(input("Enter the temp ="))
if a<=15:
    print("Temp is not convinient")
if 24<a<28:
    print("Temp is convinient")
# Out:
# Enter the temp = 26
# Temp is convinient

# %% [markdown]
# #if else statement

# %%
age = int(input("Enter your age ="))

if age>18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# Enter your age = 19
# Your are eligible to vote

# %%
base_salary = float(input("Enter your base salary = "))
work_exp = int(input("Enter your year of working="))

if work_exp >5:
    total_salary = base_salary + (0.08*base_salary) - (0.12*base_salary)
    print("You will get net salary",total_salary)
else:
    net_salary = base_salary - (0.12*base_salary)
    print("Your net salary is =",net_salary)
# Out:
# Enter your base salary =  50000
# Enter your year of working= 6
# You will get net salary 48000.0

# %% [markdown]
# #if elif else statement

# %%
a = input("Enter the city = ")
if a == "Mumbai":
    print("The famous place of mumbai is Gate way of india")
elif a == "Kolkata":
    print("The famous place of kolkata is victoria memorial")
elif a == "Chennai":
    print("The famous place of chennai is Marina Beach")
elif a == "Pune":
    print("The famous place of mumbai is Shanivar vada")
else:
    print("No Record Found")
# Out:
# Enter the city =  Chennai
# The famous place of chennai is Marina Beach
