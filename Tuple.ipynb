# %%
#tuple

# %%
a = (10,20,30)
print(a)
print(type(a))
# Out:
# (10, 20, 30)
# <class 'tuple'>

# %%
#empty tuple

# %%
tup = ()
print(tup)
print(type(tup))
# Out:
# ()
# <class 'tuple'>

# %%
#single element

# %%
b = (5)
print(b)
print(type(b))
# Out:
# 5
# <class 'int'>

# %%
b = (5,)
print(b)
print(type(b))
# Out:
# (5,)
# <class 'tuple'>

# %%
#mixedtype tuple

# %%
b = (1,2.3,"Harsh","Parth",True)
print(b)
print(type(b))
# Out:
# (1, 2.3, 'Harsh', 'Parth', True)
# <class 'tuple'>

# %%
#nested Tuple

# %%
a = ("Darji",2.5,(10,20,30))
print(a)
print(type(a))
# Out:
# ('Darji', 2.5, (10, 20, 30))
# <class 'tuple'>

# %%
num = ([12,14,16],[10,20,30],[14,78,96])
print(num)
print(type(num))
# Out:
# ([12, 14, 16], [10, 20, 30], [14, 78, 96])
# <class 'tuple'>

# %%
#tuple constructor

# %%
empty = tuple()
print(empty)
print(type(empty))
# Out:
# ()
# <class 'tuple'>

# %%
#convert list into tuple

# %%
list = [1,2,3,4]
print(list)
print(type(list))
number = tuple(list)
print(number)
print(type(number))
# Out:
# [1, 2, 3, 4]
# <class 'list'>
# (1, 2, 3, 4)
# <class 'tuple'>

# %%
#string to tuple

# %%
string = "Hello"
print(string)
print(type(string))
tuple1 = tuple(string)
print(tuple1)
print(type(tuple1))
# Out:
# Hello
# <class 'str'>
# ('H', 'e', 'l', 'l', 'o')
# <class 'tuple'>

# %%
#Dictionary to tuple

# %%
dict = {'a':1 , 'b':2, "c":3}
print(dict)
print(type(dict))
tup = tuple(dict)
print(tup)
print(type(tup))
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# <class 'dict'>
# ('a', 'b', 'c')
# <class 'tuple'>

# %%
#set to tuple

# %%
set = {1,2,3,4}
print(set)
print(type(set))

tup = tuple(set)
print(tup)
print(type(tup))
# Out:
# {1, 2, 3, 4}
# <class 'set'>
# (1, 2, 3, 4)
# <class 'tuple'>

# %%
my_list = [1,2,3,4]
print(my_list)
print(type(my_list))

a = tuple(my_list)
print(a)
print(type(a))
# Out:
# [1, 2, 3, 4]
# <class 'list'>
# (1, 2, 3, 4)
# <class 'tuple'>

# %%
#Properties in tuple
#indexing

# %%
my_tuple = ('Apple','Banana','Cherry','Date')
print(my_tuple[0])
print(my_tuple[2])
# Out:
# Apple
# Cherry

# %%
#negative indexing

# %%
my_tuple = ('Apple','Banana','Cherry','Date')
print(my_tuple[-1])
print(my_tuple[-3])
# Out:
# Date
# Banana

# %%
#slicing in tuple

# %%
my_tup = ('a','b','c','d','e')
print(my_tup[1:4])
# Out:
# ('b', 'c', 'd')

# %%
my_tup = ('a','b','c','d','e')
print(my_tup[:])
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
my_tup = ('a','b','c','d','e')
print(my_tup[:4])
# Out:
# ('a', 'b', 'c', 'd')

# %%
#jump in sliceing

# %%
my_tup = ('a','b','c','d','e')
print(my_tup[::2])
# Out:
# ('a', 'c', 'e')

# %%
#Slicing in negative indexing

# %%
tup = ('apple','banana','graps','cherry')
print(tup[:-3])
print(tup[-3:])
# Out:
# ('apple',)
# ('banana', 'graps', 'cherry')

# %%
#rverse tuple

# %%
a = (45,21,25,16,28,37,69)
print(a[::-1])
# Out:
# (69, 37, 28, 16, 25, 21, 45)

# %%
t = (1,2,3,4,5,6,7,8)
print(t[::])
print(t[3:])
print(t[:4])
print(t[:-5])
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)
# (4, 5, 6, 7, 8)
# (1, 2, 3, 4)
# (1, 2, 3)

# %%
#Duplicate are allowed in tuple

# %%
a = (12,14,15,14,53,14,15,89,12)
print(a)
# Out:
# (12, 14, 15, 14, 53, 14, 15, 89, 12)

# %%
#methods in tuple
#count methods

# %%
a = (12,14,15,14,53,14,15,89,12)
print(a.count(12))
print(a.count(14))
# Out:
# 2
# 3

# %%
b = ('Harsh','Akash','chetan','rahul','Harsh')
print(b.count('Harsh'))
print(b.count('Akash'))
# Out:
# 2
# 1

# %%
#index

# %%
b = ('Harsh','Akash','chetan','rahul','Harsh')
print(b.index('Harsh'))
print(b.index('chetan'))
# Out:
# 0
# 2

# %% [markdown]
# #part 3

# %%
#convert tuple into list

# %%
x = ("data","python","science","Xyz")
print(x)
print(type(x))

y = list(x)
print(y)
print(type(y))
# Out:
# ('data', 'python', 'science', 'Xyz')
# <class 'tuple'>
# ['data', 'python', 'science', 'Xyz']
# <class 'list'>

# %% [markdown]
# Add items

# %%
a = (25,2,27,28,29)
y = list(a)
print(y)
print(type(y))

y.append(30)
print("the new list is",y)

x = tuple(y)
print("the new item on added on tuple is",x)
# Out:
# [25, 2, 27, 28, 29]
# <class 'list'>
# the new list is [25, 2, 27, 28, 29, 30]
# the new item on added on tuple is (25, 2, 27, 28, 29, 30)

# %% [markdown]
# Add tuple into tuple

# %%
tup1 = ("data","python","science")
y = ("code",)
tup1+=y
print(tup1)

# %%
#remove items
