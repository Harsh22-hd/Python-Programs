# %%
a = 5
b = 10
print(a + b)
# Out:
# 15

# %%
a = 10.5
b = 51.2
print(a +  b)
# Out:
# 61.7

# %%
a = "Hello"
b = "World"
print(a +" "+ b)
# Out:
# Hello World

# %%
a = 2+5j
b = 5+1j
print(a + b)
# Out:
# (7+6j)

# %%
a = -5
b = 10
print(a + b)
# Out:
# 5

# %%
a = 50
b = 25
print(a - b)
# Out:
# 25

# %%
a = 10
b = 8
print(a * b)
# Out:
# 80

# %%
str = "hello"
print(str*5)
# Out:
# hellohellohellohellohello

# %%
a = 5
b = 5
print(a / b)
# Out:
# 1.0

# %%
a = 15
b = 3
print(a / b)
# Out:
# 5.0

# %%
a = 2+1j
b = 1+2j
print(a / b)
# Out:
# (0.8-0.6j)

# %%
print(12%3)
# Out:
# 0

# %%
print(19%5)
# Out:
# 4

# %%
a = 10.5683
b = 9.0564
print(a % b)
# Out:
# 1.5119000000000007

# %%
print(12//3)
# Out:
# 4

# %%
print(15//3)
# Out:
# 5

# %%
a = 2
b = 3
print(a**b)
# Out:
# 8

# %%
# BMI calculator
w = 60
h = 5
v = h**2
print(w/v)
# Out:
# 2.4

# %%
print(2.52055**2)
# Out:
# 6.3531723025

# %%
# boolean operator
a = True
print(type(a))
# Out:
# <class 'bool'>

# %%
a = False
print(type(a))
# Out:
# <class 'bool'>

# %%
# Comparison Operator
a = 5
b = 5
print(a==b)
# Out:
# True

# %%
a = 5
b = 9
print(a==b)
# Out:
# False

# %%
a = 5
b = 3
print(a!=b)
# Out:
# True

# %%
a = 3
b = 3
print(a!=b)
# Out:
# False

# %%
a = 5
b = 3
print(a>b)
# Out:
# True

# %%
a = 3
b = 45
print(a>b)
# Out:
# False

# %%
a = 15
b = 55
print(a<b)
# Out:
# True

# %%
a = 65
b = 55
print(a<b)
# Out:
# False

# %%
a = 5
b = 5
print(a>=b)
# Out:
# True

# %%
a = 5
b = 5
print(a<=b)
# Out:
# True

# %%
a = 4
b = 5
print(a>=b)
# Out:
# False

# %%
a = 4
b = 6
print(a<=b)
# Out:
# True

# %%
#Logical operator
a = True
b = False
print(a and b)
# Out:
# False

# %%
a = True
b = False
print(a or b)
# Out:
# True

# %%
a = True
b = False
print(not a)
# Out:
# False

# %%
a = True
b = False
print(not b)
# Out:
# True

# %% [markdown]
# # Practice Question

# %%
product_1 = 5*250
product_2 = 25*656
product_3 = 34*274
print("The price of product_1 =",product_1)
print("The price of product_2 =",product_2)
print("The price of product_3 =",product_3) 
print("The total of price = ",product_1 + product_2 + product_3)
# Out:
# The price of product_1 = 1250
# The price of product_2 = 16400
# The price of product_3 = 9316
# The total of price =  26966

# %%
p = 1500000
r = 8
n = 3
threshold = 120000

SI = (p*r*n)/100
print("The Simple interest",SI)
com = SI>threshold
print(com)
print("Greater than threshold")
# Out:
# The Simple interest 360000.0
# True
# Greater than threshold

# %%
pi = 3.14
b = 12
r = b**2
print("The area of circle =",pi*r)
# Out:
# The area of circle = 452.16
