# %% [markdown]
# Float Function

# %%
num = 10;
print(type(num))
a = float(num)
print(a)
print(type(a))
# Out:
# <class 'int'>
# 10.0
# <class 'float'>

# %%
a = "123"
print(type(a))
b = float(a)
print(b)
print(type(b))
# Out:
# <class 'str'>
# 123.0
# <class 'float'>

# %% [markdown]
# int Function

# %%
a = 5.66
print(type(a))
b = int(a)
print(b)
print(type(b))
# Out:
# <class 'float'>
# 5
# <class 'int'>

# %%
a = "2536"
print(type(a))
b = int(a)
print(b)
print(type(b))
# Out:
# <class 'str'>
# 2536
# <class 'int'>

# %% [markdown]
# String Function

# %%
a = 25
print(type(a))
b = str(a)
print(b)
print(type(b))
c = "2"
print(b + c)
# Out:
# <class 'int'>
# 25
# <class 'str'>
# 252

# %%
a = 5.48525
print(type(a))
b = str(a)
print(b)
print(type(b))
# Out:
# <class 'float'>
# 5.48525
# <class 'str'>

# %% [markdown]
# Complex Function

# %%
a = complex(5,6)
print(a)
# Out:
# (5+6j)

# %%
comp = complex(2,3)
print(comp)
# Out:
# (2+3j)

# %% [markdown]
# Abs Function

# %%
a = -23
print(abs(a))
# Out:
# 23

# %%
a = -2.365484
print(abs(a))
# Out:
# 2.365484

# %%
a = -3 + 4j
print(abs(a))
# Out:
# 5.0

# %% [markdown]
# Len Function

# %%
a = "Hello i am your educator harsh"
print(len(a))
# Out:
# 30

# %%
a = "Harsh Darji"
print(len(a))
# Out:
# 11

# %%
a = [12,53,65,5,4,2]
print(len(a))
# Out:
# 6

# %% [markdown]
# Practice Question

# %%
player_score = 12345.56
print("The player score is =",int(player_score))
# Out:
# The player score is = 12345

# %%
customer_database = [
    (1, 'John Doe', 'john@example.com'),
    (2, 'Jane smith', 'jane@example.com'),
    (3, 'Alice Johnson', 'alice@example.com'),
]
print("The total number of customer in database is",len(customer_database))
# Out:
# The total number of customer in database is 3

# %%
p = 250000
r = 9.34567
n = 3

Si = (p*r*n)/100
print("The simple interest is =",int(Si))
# Out:
# The simple interest is = 70092

# %%
# bin function
binary_rep = bin(10)
print(binary_rep)
# Out:
# 0b1010

# %%
z = bin(200)
print(z)
# Out:
# 0b11001000

# %%
c = bin(46631447896536)
print(c)
# Out:
# 0b1010100110100100111010111000110010000111011000

# %%
#sum function
a = [7,8,9,4,5,6,1,2,3,586,456,258,753,159]
b = sum(a)
print(b)
# Out:
# 2257

# %%
# str = ["Harsh","draji"]
# print(sum(str))
a = "Harsh"
b = "Darji"
print(a + " " + b)
# Out:
# Harsh Darji

# %%
a = [1,2,3,4,5]
start = 10
total = sum(a,start)
print(total)
# Out:
# 25

# %%
#Eval Function
x = 10
y = 5
a = "x + y * 2"
print(eval(a))
# Out:
# 20

# %%
exp = "5 / 2 + 3.5"
print(eval(exp))
print(type(exp))
# Out:
# 6.0
# <class 'str'>

# %%
x = 5
y = 2.5
z = 32
exp = "x+y-z*23/5-9*3"
print(eval(exp))
# Out:
# -166.7

# %%
# help Function
The Python help function is used to display the documentation of  modules,functions,classes,keyword,etc...

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating-point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
# ...

# %%
sum??
# Out:
# Signature: sum(iterable, /, start=0)
# Docstring:
# Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
# When the iterable is empty, return the start value.
# This function is intended specifically for use with numeric values and may
# reject non-numeric types.
# Type:      builtin_function_or_method

# %%
float??
# Out:
# Init signature: float(x=0, /)
# Docstring:      Convert a string or number to a floating-point number, if possible.
# Type:           type
# Subclasses:

# %% [markdown]
# input funcyion

# %%
name = input("Enter your name")
print("Name enterd by user is",name)
print(type(name))
# Out:
# Enter your name Harsh
# Name enterd by user is Harsh
# <class 'str'>

# %%
age = input("Enter your age")
print("Age enterd by user is",age)
print(type(age))
# Out:
# Enter your age 25
# Age enterd by user is 25
# <class 'str'>

# %% [markdown]
# Practice Questions

# %%
a = int(input("Enter 1st number"))
b = int(input("Enter 2nd number"))
sum = a + b
print(sum)
# Out:
# Enter 1st number 50
# Enter 2nd number 48
# 98

# %%
 age = int(input("Enter your age="))
 weight = int(input("Enter your weight="))
 height = float(input("Enter your height="))
Correct_age = abs(age)
print("The Correct age of user is =",Correct_age)

BMR = "88.362 + (13.397 * weight) + (4.799 * height) - (5.677 * age)"
bmr = eval(BMR)
print("The BMR of the patient is =",bmr)
# Out:
# Enter your age= 30
# Enter your weight= 65
# Enter your height= 5.2
# The Correct age of user is = 30
# The BMR of the patient is = 813.8118

# %%
s1 = input("Enter Your Name =")
c1 = input("Entre Your Course")
a1 = int(input("Enter Your age="))

s2 = input("Enter Your Name =")
c2 = input("Entre Your Course")
a2 = int(input("Enter Your age="))

s3 = input("Enter Your Name =")
c3 = input("Entre Your Course")
a3 = int(input("Enter Your age="))

s4 = input("Enter Your Name =")
c4 = input("Entre Your Course")
a4 = int(input("Enter Your age="))

s5 = input("Enter Your Name =")
c5 = input("Entre Your Course")
a5 = int(input("Enter Your age="))

print(f"1. {s1} - {c1} - age={a1}:")
print(f"1. {s2} - {c2} - age={a2}:")
print(f"1. {s3} - {c3} - age={a3}:")
print(f"1. {s4} - {c4} - age={a4}:")
print(f"1. {s5} - {c5} - age={a5}:")

avg_age = (a1 + a2 + a3 + a4 + a5) / 5;
print("The avg of all is = ",avg_age)
# Out:
# Enter Your Name = SVZFG
# Entre Your Course ARGZREG
# Enter Your age= 21
# Enter Your Name = Argaq
# Entre Your Course whtsytzh
# Enter Your age= 21
# Enter Your Name = aerega
# Entre Your Course awergt
# Enter Your age= 20
# Enter Your Name = AWQERF
# Entre Your Course AWRQEGF
# Enter Your age= 19
# Enter Your Name = AWERQ
# Entre Your Course wert
# Enter Your age= 20
# 1. SVZFG - ARGZREG - age=21:
# 1. Argaq - whtsytzh - age=21:
# 1. aerega - awergt - age=20:
# 1. AWQERF - AWRQEGF - age=19:
# 1. AWERQ - wert - age=20:
# The avg of all is =  20.2
