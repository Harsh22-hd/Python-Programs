# %%
x=5
print(x)
# Out:
# 5

# %%
a = 10
b = 10.5
c = "Harsh"
print(a , b ,c)
# Out:
# 10 10.5 Harsh

# %%
d = "We are learning python"
print(d)
# Out:
# We are learning python

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      10
# b          float    10.5
# c          str      Harsh
# d          str      We are learning python
# x          int      5
